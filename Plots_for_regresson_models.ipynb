# %% [markdown]
# ## Plots of all regresson models: True vs Predicted values

# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
import yaml
import pprint

# %matplotlib inline
from util import get_true_predicted_crossvalid

import warnings
warnings.filterwarnings("ignore")

# %%
from xrsdkit.tools.profiler import profile_keys
from xrsdkit.tools.ymltools import read_local_dataset

# %%
df, idx_df = read_local_dataset('../xrsdkit_modeling/flowreactor_pd_nanoparticles/dataset', downsampling_distance=1)
# Out:
# loading data from RxnA_20190329_0_xrsd_system.yml
# loading data from RxnA_20190329_7_xrsd_system.yml
# loading data from RxnA_20190329_10_xrsd_system.yml
# loading data from RxnA_20190329_8_xrsd_system.yml
# loading data from RxnA_20190329_6_xrsd_system.yml
# loading data from RxnA_20190329_9_xrsd_system.yml
# loading data from RxnA_20190329_11_xrsd_system.yml
# loading data from RxnA_20190329_1_xrsd_system.yml
# loading data from RxnA_20190329_4_xrsd_system.yml
# loading data from RxnA_20190329_13_xrsd_system.yml
# loading data from RxnA_20190329_14_xrsd_system.yml
# loading data from RxnA_20190329_3_xrsd_system.yml
# loading data from RxnA_20190329_15_xrsd_system.yml
# loading data from RxnA_20190329_2_xrsd_system.yml
# loading data from RxnA_20190329_5_xrsd_system.yml
# loading data from RxnA_20190329_12_xrsd_system.yml
# loading data from RxnD_201902_21_xrsd_system.yml
# loading data from RxnD_201902_13_xrsd_system.yml
# loading data from RxnD_201902_2_xrsd_system.yml
# loading data from RxnD_201902_5_xrsd_system.yml
# loading data from RxnD_201902_14_xrsd_system.yml
# loading data from RxnD_201902_4_xrsd_system.yml
# loading data from RxnD_201902_15_xrsd_system.yml
# loading data from RxnD_201902_20_xrsd_system.yml
# loading data from RxnD_201902_12_xrsd_system.yml
# loading data from RxnD_201902_3_xrsd_system.yml
# loading data from RxnD_201902_6_xrsd_system.yml
# loading data from RxnD_201902_17_xrsd_system.yml
# loading data from RxnD_201902_18_xrsd_system.yml
# loading data from RxnD_201902_9_xrsd_system.yml
# loading data from RxnD_201902_22_xrsd_system.yml
# loading data from RxnD_201902_10_xrsd_system.yml
# loading data from RxnD_201902_1_xrsd_system.yml
# loading data from RxnD_201902_11_xrsd_system.yml
# loading data from RxnD_201902_0_xrsd_system.yml
# loading data from RxnD_201902_7_xrsd_system.yml
# loading data from RxnD_201902_16_xrsd_system.yml
# loading data from RxnD_201902_19_xrsd_system.yml
# loading data from RxnD_201902_8_xrsd_system.yml
# loading data from R6_20190417_1_xrsd_system.yml
# loading data from R6_20190417_6_xrsd_system.yml
# loading data from R6_20190417_9_xrsd_system.yml
# loading data from R6_20190417_7_xrsd_system.yml
# loading data from R6_20190417_8_xrsd_system.yml
# loading data from R6_20190417_0_xrsd_system.yml
# loading data from R6_20190417_5_xrsd_system.yml
# loading data from R6_20190417_2_xrsd_system.yml
# loading data from R6_20190417_10_xrsd_system.yml
# loading data from R6_20190417_3_xrsd_system.yml
# loading data from R6_20190417_4_xrsd_system.yml
# loading data from R7_20190417_0_xrsd_system.yml
# loading data from R7_20190417_1_xrsd_system.yml
# loading data from R7_20190417_4_xrsd_system.yml
# loading data from R7_20190417_3_xrsd_system.yml
# loading data from R7_20190417_2_xrsd_system.yml
# loading data from R7_20190417_5_xrsd_system.yml
# loading data from randomized_goal10_xrsd_system.yml
# loading data from randomized_goal1_xrsd_system.yml
# loading data from randomized_goal22_xrsd_system.yml
# loading data from randomized_goal9_xrsd_system.yml
# loading data from randomized_goal25_xrsd_system.yml
# loading data from randomized_goal18_xrsd_system.yml
# loading data from randomized_goal6_xrsd_system.yml
# loading data from randomized_goal17_xrsd_system.yml
# loading data from randomized_goal33_xrsd_system.yml
# loading data from randomized_goal24_xrsd_system.yml
# loading data from randomized_goal19_xrsd_system.yml
# loading data from randomized_goal8_xrsd_system.yml
# loading data from randomized_goal16_xrsd_system.yml
# loading data from randomized_goal7_xrsd_system.yml
# loading data from randomized_goal32_xrsd_system.yml
# loading data from randomized_goal0_xrsd_system.yml
# loading data from randomized_goal11_xrsd_system.yml
# loading data from randomized_goal23_xrsd_system.yml
# loading data from randomized_goal26_xrsd_system.yml
# loading data from randomized_goal30_xrsd_system.yml
# loading data from randomized_goal29_xrsd_system.yml
# loading data from randomized_goal14_xrsd_system.yml
# loading data from randomized_goal5_xrsd_system.yml
# loading data from randomized_goal2_xrsd_system.yml
# loading data from randomized_goal13_xrsd_system.yml
# loading data from randomized_goal21_xrsd_system.yml
# loading data from randomized_goal12_xrsd_system.yml
# loading data from randomized_goal3_xrsd_system.yml
# loading data from randomized_goal20_xrsd_system.yml
# loading data from randomized_goal27_xrsd_system.yml
# loading data from randomized_goal31_xrsd_system.yml
# loading data from randomized_goal4_xrsd_system.yml
# loading data from randomized_goal28_xrsd_system.yml
# loading data from randomized_goal15_xrsd_system.yml
# loading data from RxnB_201902_0_xrsd_system.yml
# loading data from RxnB_201902_11_xrsd_system.yml
# loading data from RxnB_201902_8_xrsd_system.yml
# loading data from RxnB_201902_16_xrsd_system.yml
# loading data from RxnB_201902_19_xrsd_system.yml
# loading data from RxnB_201902_7_xrsd_system.yml
# loading data from RxnB_201902_9_xrsd_system.yml
# loading data from RxnB_201902_17_xrsd_system.yml
# loading data from RxnB_201902_18_xrsd_system.yml
# loading data from RxnB_201902_6_xrsd_system.yml
# loading data from RxnB_201902_1_xrsd_system.yml
# loading data from RxnB_201902_10_xrsd_system.yml
# loading data from RxnB_201902_15_xrsd_system.yml
# loading data from RxnB_201902_4_xrsd_system.yml
# loading data from RxnB_201902_3_xrsd_system.yml
# loading data from RxnB_201902_12_xrsd_system.yml
# loading data from RxnB_201902_2_xrsd_system.yml
# loading data from RxnB_201902_13_xrsd_system.yml
# loading data from RxnB_201902_14_xrsd_system.yml
# loading data from RxnB_201902_5_xrsd_system.yml
# loading data from R2_20190424_3_xrsd_system.yml
# loading data from R2_20190424_4_xrsd_system.yml
# loading data from R2_20190424_5_xrsd_system.yml
# loading data from R2_20190424_2_xrsd_system.yml
# loading data from R2_20190424_7_xrsd_system.yml
# loading data from R2_20190424_8_xrsd_system.yml
# loading data from R2_20190424_0_xrsd_system.yml
# loading data from R2_20190424_1_xrsd_system.yml
# loading data from R2_20190424_6_xrsd_system.yml
# loading data from RxnB_201903_8_xrsd_system.yml
# loading data from RxnB_201903_14_xrsd_system.yml
# loading data from RxnB_201903_26_xrsd_system.yml
# loading data from RxnB_201903_7_xrsd_system.yml
# loading data from RxnB_201903_0_xrsd_system.yml
# loading data from RxnB_201903_21_xrsd_system.yml
# loading data from RxnB_201903_13_xrsd_system.yml
# loading data from RxnB_201903_1_xrsd_system.yml
# loading data from RxnB_201903_20_xrsd_system.yml
# loading data from RxnB_201903_12_xrsd_system.yml
# loading data from RxnB_201903_9_xrsd_system.yml
# loading data from RxnB_201903_15_xrsd_system.yml
# loading data from RxnB_201903_6_xrsd_system.yml
# loading data from RxnB_201903_22_xrsd_system.yml
# loading data from RxnB_201903_3_xrsd_system.yml
# loading data from RxnB_201903_10_xrsd_system.yml
# loading data from RxnB_201903_17_xrsd_system.yml
# loading data from RxnB_201903_4_xrsd_system.yml
# loading data from RxnB_201903_25_xrsd_system.yml
# loading data from RxnB_201903_18_xrsd_system.yml
# loading data from RxnB_201903_16_xrsd_system.yml
# loading data from RxnB_201903_5_xrsd_system.yml
# loading data from RxnB_201903_24_xrsd_system.yml
# loading data from RxnB_201903_19_xrsd_system.yml
# loading data from RxnB_201903_23_xrsd_system.yml
# loading data from RxnB_201903_2_xrsd_system.yml
# loading data from RxnB_201903_11_xrsd_system.yml
# loading data from R5_20190417_2_xrsd_system.yml
# loading data from R5_20190417_5_xrsd_system.yml
# loading data from R5_20190417_10_xrsd_system.yml
# loading data from R5_20190417_4_xrsd_system.yml
# loading data from R5_20190417_3_xrsd_system.yml
# loading data from R5_20190417_6_xrsd_system.yml
# loading data from R5_20190417_9_xrsd_system.yml
# loading data from R5_20190417_1_xrsd_system.yml
# loading data from R5_20190417_0_xrsd_system.yml
# loading data from R5_20190417_7_xrsd_system.yml
# loading data from R5_20190417_8_xrsd_system.yml
# loading data from R4_20190417_3_xrsd_system.yml
# loading data from R4_20190417_4_xrsd_system.yml
# loading data from R4_20190417_5_xrsd_system.yml
# loading data from R4_20190417_10_xrsd_system.yml
# loading data from R4_20190417_2_xrsd_system.yml
# loading data from R4_20190417_7_xrsd_system.yml
# loading data from R4_20190417_8_xrsd_system.yml
# loading data from R4_20190417_0_xrsd_system.yml
# loading data from R4_20190417_1_xrsd_system.yml
# loading data from R4_20190417_6_xrsd_system.yml
# loading data from R4_20190417_9_xrsd_system.yml
# loading data from RxnE_201902_19_xrsd_system.yml
# loading data from RxnE_201902_24_xrsd_system.yml
# loading data from RxnE_201902_16_xrsd_system.yml
# loading data from RxnE_201902_3_xrsd_system.yml
# loading data from RxnE_201902_4_xrsd_system.yml
# loading data from RxnE_201902_11_xrsd_system.yml
# loading data from RxnE_201902_23_xrsd_system.yml
# loading data from RxnE_201902_10_xrsd_system.yml
# loading data from RxnE_201902_5_xrsd_system.yml
# loading data from RxnE_201902_22_xrsd_system.yml
# loading data from RxnE_201902_18_xrsd_system.yml
# loading data from RxnE_201902_25_xrsd_system.yml
# loading data from RxnE_201902_2_xrsd_system.yml
# loading data from RxnE_201902_17_xrsd_system.yml
# loading data from RxnE_201902_12_xrsd_system.yml
# loading data from RxnE_201902_7_xrsd_system.yml
# loading data from RxnE_201902_20_xrsd_system.yml
# loading data from RxnE_201902_8_xrsd_system.yml
# loading data from RxnE_201902_27_xrsd_system.yml
# loading data from RxnE_201902_0_xrsd_system.yml
# loading data from RxnE_201902_15_xrsd_system.yml
# loading data from RxnE_201902_26_xrsd_system.yml
# loading data from RxnE_201902_14_xrsd_system.yml
# loading data from RxnE_201902_1_xrsd_system.yml
# loading data from RxnE_201902_6_xrsd_system.yml
# loading data from RxnE_201902_13_xrsd_system.yml
# loading data from RxnE_201902_9_xrsd_system.yml
# loading data from RxnE_201902_21_xrsd_system.yml
# loading data from RxnB_20190329_12_xrsd_system.yml
# loading data from RxnB_20190329_3_xrsd_system.yml
# loading data from RxnB_20190329_20_xrsd_system.yml
# loading data from RxnB_20190329_27_xrsd_system.yml
# loading data from RxnB_20190329_4_xrsd_system.yml
# loading data from RxnB_20190329_15_xrsd_system.yml
# loading data from RxnB_20190329_28_xrsd_system.yml
# loading data from RxnB_20190329_26_xrsd_system.yml
# loading data from RxnB_20190329_5_xrsd_system.yml
# loading data from RxnB_20190329_30_xrsd_system.yml
# loading data from RxnB_20190329_14_xrsd_system.yml
# loading data from RxnB_20190329_29_xrsd_system.yml
# loading data from RxnB_20190329_13_xrsd_system.yml
# loading data from RxnB_20190329_2_xrsd_system.yml
# loading data from RxnB_20190329_21_xrsd_system.yml
# loading data from RxnB_20190329_19_xrsd_system.yml
# loading data from RxnB_20190329_7_xrsd_system.yml
# loading data from RxnB_20190329_24_xrsd_system.yml
# loading data from RxnB_20190329_16_xrsd_system.yml
# loading data from RxnB_20190329_8_xrsd_system.yml
# loading data from RxnB_20190329_11_xrsd_system.yml
# loading data from RxnB_20190329_23_xrsd_system.yml
# loading data from RxnB_20190329_0_xrsd_system.yml
# loading data from RxnB_20190329_10_xrsd_system.yml
# loading data from RxnB_20190329_22_xrsd_system.yml
# loading data from RxnB_20190329_1_xrsd_system.yml
# loading data from RxnB_20190329_6_xrsd_system.yml
# loading data from RxnB_20190329_18_xrsd_system.yml
# loading data from RxnB_20190329_25_xrsd_system.yml
# loading data from RxnB_20190329_9_xrsd_system.yml
# loading data from RxnB_20190329_17_xrsd_system.yml
# loading data from RxnA_201902_3_xrsd_system.yml
# loading data from RxnA_201902_4_xrsd_system.yml
# loading data from RxnA_201902_5_xrsd_system.yml
# loading data from RxnA_201902_2_xrsd_system.yml
# loading data from RxnA_201902_7_xrsd_system.yml
# loading data from RxnA_201902_8_xrsd_system.yml
# loading data from RxnA_201902_0_xrsd_system.yml
# loading data from RxnA_201902_1_xrsd_system.yml
# loading data from RxnA_201902_6_xrsd_system.yml
# loading data from RxnA_201902_9_xrsd_system.yml
# loading data from R1_20190424_0_xrsd_system.yml
# loading data from R1_20190424_7_xrsd_system.yml
# loading data from R1_20190424_8_xrsd_system.yml
# loading data from R1_20190424_6_xrsd_system.yml
# loading data from R1_20190424_9_xrsd_system.yml
# loading data from R1_20190424_1_xrsd_system.yml
# loading data from R1_20190424_4_xrsd_system.yml
# loading data from R1_20190424_3_xrsd_system.yml
# loading data from R1_20190424_2_xrsd_system.yml
# loading data from R1_20190424_5_xrsd_system.yml
# loading data from R0_20190424_1_xrsd_system.yml
# loading data from R0_20190424_6_xrsd_system.yml
# loading data from R0_20190424_9_xrsd_system.yml
# loading data from R0_20190424_7_xrsd_system.yml
# loading data from R0_20190424_8_xrsd_system.yml
# loading data from R0_20190424_0_xrsd_system.yml
# loading data from R0_20190424_5_xrsd_system.yml
# loading data from R0_20190424_2_xrsd_system.yml
# loading data from R0_20190424_3_xrsd_system.yml
# loading data from R0_20190424_4_xrsd_system.yml
# loading data from gridsearch22_xrsd_system.yml
# loading data from gridsearch10_xrsd_system.yml
# loading data from gridsearch4_xrsd_system.yml
# loading data from gridsearch3_xrsd_system.yml
# loading data from gridsearch17_xrsd_system.yml
# loading data from gridsearch33_xrsd_system.yml
# loading data from gridsearch18_xrsd_system.yml
# loading data from gridsearch25_xrsd_system.yml
# loading data from gridsearch2_xrsd_system.yml
# loading data from gridsearch16_xrsd_system.yml
# loading data from gridsearch32_xrsd_system.yml
# loading data from gridsearch19_xrsd_system.yml
# loading data from gridsearch24_xrsd_system.yml
# loading data from gridsearch23_xrsd_system.yml
# loading data from gridsearch11_xrsd_system.yml
# loading data from gridsearch5_xrsd_system.yml
# loading data from gridsearch30_xrsd_system.yml
# loading data from gridsearch14_xrsd_system.yml
# loading data from gridsearch0_xrsd_system.yml
# loading data from gridsearch29_xrsd_system.yml
# loading data from gridsearch26_xrsd_system.yml
# loading data from gridsearch8_xrsd_system.yml
# loading data from gridsearch21_xrsd_system.yml
# loading data from gridsearch7_xrsd_system.yml
# loading data from gridsearch13_xrsd_system.yml
# loading data from gridsearch9_xrsd_system.yml
# loading data from gridsearch20_xrsd_system.yml
# loading data from gridsearch6_xrsd_system.yml
# loading data from gridsearch12_xrsd_system.yml
# loading data from gridsearch31_xrsd_system.yml
# loading data from gridsearch15_xrsd_system.yml
# loading data from gridsearch1_xrsd_system.yml
# loading data from gridsearch28_xrsd_system.yml
# loading data from gridsearch27_xrsd_system.yml
# loading data from RxnA_201903_4_xrsd_system.yml
# loading data from RxnA_201903_10_xrsd_system.yml
# loading data from RxnA_201903_3_xrsd_system.yml
# loading data from RxnA_201903_11_xrsd_system.yml
# loading data from RxnA_201903_2_xrsd_system.yml
# loading data from RxnA_201903_5_xrsd_system.yml
# loading data from RxnA_201903_13_xrsd_system.yml
# loading data from RxnA_201903_0_xrsd_system.yml
# loading data from RxnA_201903_7_xrsd_system.yml
# loading data from RxnA_201903_8_xrsd_system.yml
# loading data from RxnA_201903_6_xrsd_system.yml
# loading data from RxnA_201903_9_xrsd_system.yml
# loading data from RxnA_201903_12_xrsd_system.yml
# loading data from RxnA_201903_1_xrsd_system.yml
# loading data from RxnC_201903_11_xrsd_system.yml
# loading data from RxnC_201903_9_xrsd_system.yml
# loading data from RxnC_201903_6_xrsd_system.yml
# loading data from RxnC_201903_1_xrsd_system.yml
# loading data from RxnC_201903_0_xrsd_system.yml
# loading data from RxnC_201903_10_xrsd_system.yml
# loading data from RxnC_201903_8_xrsd_system.yml
# loading data from RxnC_201903_7_xrsd_system.yml
# loading data from RxnC_201903_2_xrsd_system.yml
# loading data from RxnC_201903_15_xrsd_system.yml
# loading data from RxnC_201903_12_xrsd_system.yml
# loading data from RxnC_201903_5_xrsd_system.yml
# loading data from RxnC_201903_13_xrsd_system.yml
# loading data from RxnC_201903_4_xrsd_system.yml
# loading data from RxnC_201903_3_xrsd_system.yml
# loading data from RxnC_201903_14_xrsd_system.yml
# loading data from randomized_goalB18_xrsd_system.yml
# loading data from randomized_goalB17_xrsd_system.yml
# loading data from randomized_goalB1_xrsd_system.yml
# loading data from randomized_goalB6_xrsd_system.yml
# loading data from randomized_goalB10_xrsd_system.yml
# loading data from randomized_goalB9_xrsd_system.yml
# loading data from randomized_goalB7_xrsd_system.yml
# loading data from randomized_goalB11_xrsd_system.yml
# loading data from randomized_goalB8_xrsd_system.yml
# loading data from randomized_goalB19_xrsd_system.yml
# loading data from randomized_goalB16_xrsd_system.yml
# loading data from randomized_goalB0_xrsd_system.yml
# loading data from randomized_goalB13_xrsd_system.yml
# loading data from randomized_goalB5_xrsd_system.yml
# loading data from randomized_goalB2_xrsd_system.yml
# loading data from randomized_goalB14_xrsd_system.yml
# loading data from randomized_goalB3_xrsd_system.yml
# loading data from randomized_goalB15_xrsd_system.yml
# loading data from randomized_goalB12_xrsd_system.yml
# loading data from randomized_goalB4_xrsd_system.yml
# loading data from RxnC_201902_1_xrsd_system.yml
# loading data from RxnC_201902_6_xrsd_system.yml
# loading data from RxnC_201902_0_xrsd_system.yml
# loading data from RxnC_201902_5_xrsd_system.yml
# loading data from RxnC_201902_2_xrsd_system.yml
# loading data from RxnC_201902_3_xrsd_system.yml
# loading data from RxnC_201902_4_xrsd_system.yml
# Downsampling data for group: ('R0_201811', 'diffuse')
# Finished downsampling: kept 4/4
# Downsampling data for group: ('R0_201811', 'diffuse__diffuse')
# Finished downsampling: kept 15/15
# Downsampling data for group: ('R0_201811', 'diffuse__diffuse__disordered')
# Finished downsampling: kept 6/6
# Downsampling data for group: ('R0_201811', 'unidentified')
# Finished downsampling: kept 4/4
# Downsampling data for group: ('R0_20190424', 'diffuse')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('R0_20190424', 'diffuse__diffuse')
# Finished downsampling: kept 8/8
# Downsampling data for group: ('R0_20190424', 'unidentified')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('R1_201811', 'diffuse')
# Finished downsampling: kept 17/17
# Downsampling data for group: ('R1_201811', 'diffuse__diffuse')
# Finished downsampling: kept 9/9
# Downsampling data for group: ('R1_201811', 'diffuse__disordered')
# Finished downsampling: kept 2/2
# Downsampling data for group: ('R1_201811', 'unidentified')
# Finished downsampling: kept 2/2
# Downsampling data for group: ('R1_20190424', 'diffuse__diffuse')
# Finished downsampling: kept 5/5
# Downsampling data for group: ('R1_20190424', 'diffuse__diffuse__disordered')
# Finished downsampling: kept 4/4
# Downsampling data for group: ('R1_20190424', 'diffuse__disordered')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('R2_201811', 'diffuse')
# Finished downsampling: kept 2/2
# Downsampling data for group: ('R2_201811', 'diffuse__diffuse')
# Finished downsampling: kept 4/4
# Downsampling data for group: ('R2_201811', 'diffuse__diffuse__disordered')
# Finished downsampling: kept 4/4
# Downsampling data for group: ('R2_201811', 'diffuse__disordered')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('R2_20190424', 'diffuse')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('R2_20190424', 'diffuse__diffuse')
# Finished downsampling: kept 4/4
# Downsampling data for group: ('R2_20190424', 'diffuse__diffuse__disordered')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('R2_20190424', 'unidentified')
# Finished downsampling: kept 2/2
# Downsampling data for group: ('R4_20190417', 'diffuse')
# Finished downsampling: kept 2/2
# Downsampling data for group: ('R4_20190417', 'diffuse__diffuse')
# Finished downsampling: kept 8/8
# Downsampling data for group: ('R4_20190417', 'diffuse__diffuse__disordered')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('R5_20190417', 'diffuse')
# Finished downsampling: kept 3/3
# Downsampling data for group: ('R5_20190417', 'diffuse__diffuse')
# Finished downsampling: kept 7/7
# Downsampling data for group: ('R5_20190417', 'unidentified')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('R6_20190417', 'diffuse')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('R6_20190417', 'diffuse__diffuse')
# Finished downsampling: kept 9/9
# Downsampling data for group: ('R6_20190417', 'unidentified')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('R7_20190417', 'diffuse__diffuse')
# Finished downsampling: kept 4/4
# Downsampling data for group: ('RxnA_201902', 'diffuse')
# Finished downsampling: kept 4/4
# Downsampling data for group: ('RxnA_201902', 'diffuse__diffuse__disordered')
# Finished downsampling: kept 2/2
# Downsampling data for group: ('RxnA_201902', 'unidentified')
# Finished downsampling: kept 2/2
# Downsampling data for group: ('RxnA_201903', 'diffuse')
# Finished downsampling: kept 4/4
# Downsampling data for group: ('RxnA_201903', 'diffuse__diffuse')
# Finished downsampling: kept 9/9
# Downsampling data for group: ('RxnA_201903', 'diffuse__diffuse__disordered')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('RxnA_20190329', 'diffuse')
# Finished downsampling: kept 2/2
# Downsampling data for group: ('RxnA_20190329', 'diffuse__diffuse')
# Finished downsampling: kept 5/5
# Downsampling data for group: ('RxnA_20190329', 'unidentified')
# Finished downsampling: kept 6/6
# Downsampling data for group: ('RxnB_201902', 'diffuse')
# Finished downsampling: kept 4/4
# Downsampling data for group: ('RxnB_201902', 'diffuse__diffuse')
# Finished downsampling: kept 6/6
# Downsampling data for group: ('RxnB_201902', 'diffuse__diffuse__disordered')
# Finished downsampling: kept 2/2
# Downsampling data for group: ('RxnB_201902', 'diffuse__disordered')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('RxnB_201902', 'unidentified')
# Finished downsampling: kept 5/5
# Downsampling data for group: ('RxnB_201903', 'diffuse')
# Finished downsampling: kept 6/6
# Downsampling data for group: ('RxnB_201903', 'diffuse__diffuse')
# Finished downsampling: kept 18/18
# Downsampling data for group: ('RxnB_201903', 'unidentified')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('RxnB_20190329', 'diffuse')
# Finished downsampling: kept 4/4
# Downsampling data for group: ('RxnB_20190329', 'diffuse__diffuse')
# Finished downsampling: kept 5/5
# Downsampling data for group: ('RxnB_20190329', 'diffuse__diffuse__disordered')
# Finished downsampling: kept 7/7
# Downsampling data for group: ('RxnB_20190329', 'unidentified')
# Finished downsampling: kept 9/9
# Downsampling data for group: ('RxnC_201902', 'diffuse')
# Finished downsampling: kept 4/4
# Downsampling data for group: ('RxnC_201902', 'diffuse__disordered')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('RxnC_201903', 'diffuse')
# Finished downsampling: kept 3/3
# Downsampling data for group: ('RxnC_201903', 'diffuse__diffuse')
# Finished downsampling: kept 9/9
# Downsampling data for group: ('RxnC_201903', 'unidentified')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('RxnD_201902', 'diffuse')
# Finished downsampling: kept 5/5
# Downsampling data for group: ('RxnD_201902', 'diffuse__diffuse')
# Finished downsampling: kept 9/9
# Downsampling data for group: ('RxnD_201902', 'diffuse__disordered')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('RxnD_201902', 'unidentified')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('RxnE_201902', 'diffuse')
# Finished downsampling: kept 6/6
# Downsampling data for group: ('RxnE_201902', 'diffuse__diffuse')
# Finished downsampling: kept 13/13
# Downsampling data for group: ('RxnE_201902', 'diffuse__diffuse__disordered')
# Finished downsampling: kept 1/1
# Downsampling data for group: ('RxnE_201902', 'unidentified')
# Finished downsampling: kept 1/1

# %% [markdown]
# ### Regression models for the System Class "Diffuse"

# %%
diffuse_res = get_true_predicted_crossvalid('diffuse', df)

# %%
for k, v in diffuse_res.items():
    fig, ax = plt.subplots(1,1, figsize=(10,6))
    x = v['true_y']
    y = v['cross_val']
    plt.scatter(x, y, marker='^')
    z = v['predicted']
    plt.scatter(x, z, marker='o')
    plt.plot(x, x, 'b--')
    ax.set_title(k)
    ax.legend(["true_val", 'cross_val', 'predicted'])

# %% [markdown]
# ### Regression models for the System Class "Diffuse_diffuse"

# %%
dif_dif_res = get_true_predicted_crossvalid('diffuse__diffuse', df)
for k, v in dif_dif_res.items():
    fig, ax = plt.subplots(1,1, figsize=(7,4))
    x = v['true_y']
    y = v['cross_val']
    plt.scatter(x, y, marker='^')
    z = v['predicted']
    plt.scatter(x, z, marker='o')
    plt.plot(x, x, 'b--')
    ax.set_title(k)
    ax.legend(["true_val", 'cross_val', 'predicted'])

# %% [markdown]
# ### Regression models for the System Class "Diffuse_diffuse_disordered"

# %%
dif_dif_dis_res = get_true_predicted_crossvalid('diffuse__diffuse__disordered', df)
for k, v in dif_dif_dis_res.items():
    fig, ax = plt.subplots(1,1, figsize=(7,4))
    x = v['true_y']
    y = v['cross_val']
    plt.scatter(x, y, marker='^')
    z = v['predicted']
    plt.scatter(x, z, marker='o')
    plt.plot(x, x, 'b--')
    ax.set_title(k)
    ax.legend(["true_val", 'cross_val', 'predicted'])

# %% [markdown]
# ### Regression models for the System Class "Diffuse_disordered"

# %%
dif_dis_res = get_true_predicted_crossvalid('diffuse__disordered', df)
dif_dis_res
# Out:
# {}

# %% [markdown]
# We have no models for diffuse_disordered system class.
